# %% [markdown]
# # TFT

# %% [markdown]
# ### latency

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def plot(data):
    data = dict(sorted(data.items()))
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(list(data.keys()), list(data.values()), marker='o', linestyle='--')
    ax.set_xlabel( 'Latency', fontsize=15)
    ax.set_ylabel('Sum of active layers', fontsize=15)
    ax.tick_params(axis='both', which='major', labelsize=12)
    #ax.legend()

# %%
data_04= {
    #15: 6.11,
    37: 17.11,
    38: 18.27,
    39: 19.37,
    40: 20.24,
    41: 20.49,
    42: 20.50,
    43: 20.34,
    44: 7.39,
    45: 1.73,
    46: 0.51
}
plot(data_04)

# %%
data_08 = {
    42: 3.91,
    43: 4.15,
    44: 4.42,
    45: 4.72,
    46: 5.09,
    47: 5.57,
    48: 6.16,
    49: 6.85,
    50: 7.63,
    51: 8.53,
    52: 9.90,
    53: 11.78,
    54: 15.14,
    55: 19.46,
    56: 20.47,
    57: 20.37,
    58: 4.22,
    59: 0.56,
    60: 0.51
}
plot(data_08)

# %%
# f = 1 kHz, V_h = 3.370 V, width = 20 ns
data_09 = {
    37: 9.20,
    38: 10.55,
    39: 12.54,
    40: 15.77 ,
    41: 19.64,
    42: 20.47,
    43: 20.39,
    44: 4.30,
    45: 0.57,
    46: 0.51 
    
}
plot(data_09)

# %%
# f = 1 kHz, V_h = 3.300 V, width = 20 ns

# %%
data_11 = {
    37: 4.77,
    38: 5.44,
    39: 5.32,
    40: 7.75,
    41: 10.64,
    42: 17.07,
    43: 20.35,
    44: 20.21,
    45: 2.75,
    46: 0.62,
    47: 0.52
    
}
plot(data_11)

# %%
data_11_v2 = {
    37: 4.72,
    38: 4.76,
    39: 6.30,
    40: 7.70,
    41: 10.59,
    42: 16.98,
    43: 20.37,
    44: 20.23,
    45: 2.81,
    46: 0.55,
    47: 0.514
    
}
plot(data_11_v2)

# %%
# bias voltage = 255, pulse width = 60 ns, LED 1
data_REAL = {
    43: 0.59,
    46: 0.62,
    49: 0.64,
    52: 0.69,
    55: 0.73,
    58: 0.79,
    61: 0.85,
    64: 0.92,
    70: 1.05,
    76: 1.07,
    82: 1.1,
    88: 1.11,
    94: 1.17,
    100: 1.42,
    106: 1.82,
    112: 4.97,
    118: 14.79,
    124: 5.13,  #1740479057
    119: 17.94,
    120: 18.04, # 1740479306
    121: 18.26,
    122: 20.10, #1740479589
    123: 19.91,
    124: 5.80,
    
    
    
    130: 0.50,
    133: 0.5,
    136: 0.5,
}
plot(data_REAL)

# %%
# bias voltage = 255, pulse width = 30 ns, LED 1 
# -> 1 kHz triggers

# bias voltage = 255, pulse width = 20 ns, LED 1 
# -> 1 kHz triggers

# bias voltage = 255, pulse width = 10 ns, LED 1 
# -> 1 kHz triggers

# bias voltage = 255, pulse width = 0 ns, LED 1 
# -> 791 Hz triggers

# bias voltage = 245, pulse width = 0 ns, LED 1 
# -> 630 Hz triggers

# bias voltage = 235, pulse width = 0 ns, LED 1 
# -> 421 Hz triggers

# %%
#scan here then find correct configuration of LED 2 around (300 / 400 Hz)

# %%
# bias voltage = 235, pulse width = 0 ns, LED 1
data_lower_light = {
    122: 18.89, # 1740486942
    123: 18.07,
    124: 0.62,
    125: 0.50,
    121:2.72, 
    120: 0.70,
    119: 0.62,
    123: 18.29, #1740489672
    
}

plot(data_lower_light)

# %%
# bias voltage = 235, pulse width = 0 ns, LED 2
# -> 560 Hz triggers

# bias voltage = 225, pulse width = 0 ns, LED 2
# -> 303 Hz triggers

# bias voltage = 230, pulse width = 0 ns, LED 2
# -> 440 Hz triggers
